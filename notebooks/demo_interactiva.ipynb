# %% [markdown]
# # 📄 Asistente RAG para Análisis de Documentos PDF

# %% [markdown]
# ## 🧠 RAG Pipeline: Experimentación y Pruebas

# %%
# Carga de dependencias
import os
from dotenv import load_dotenv
load_dotenv() # Cargamos nuestra API Key desde .env
# Importaciones clave de LangChain y Google
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_chroma import Chroma

# %% [markdown]
# ## 📄 Capítulo 1: Ingesta de Datos y Fragmentación Semántica
